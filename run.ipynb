# %%
import datetime

from util.util import importstr
from util.logconf import logging
log = logging.getLogger('nb')

# %%
def run(app, *argv):
    argv = list(argv)
    argv.insert(0, '--num-workers=4')
    log.info(f'Running {app} with args: {argv}')

    app_cls = importstr(*app.rsplit('.', 1))
    app_cls(argv).main()

    log.info(f'Finished running {app}.{argv}.main()')

# %%
import os
import shutil

def cleanCache():
    shutil.rmtree('data-unversioned/cache')
    os.mkdir('data-unversioned/cache')

cleanCache()

# %%
training_epochs = 20
experiment_epochs = 10
final_epochs = 50

training_epochs = 2
experiment_epochs = 2
final_epochs = 5
seg_epochs = 10

# %% [markdown]
# ### Prep Cache

# %%
run('src.prepcache.LunaPrepCacheApp')
# Out:
# 2026-02-08 19:07:00,545 INFO     pid:476573 nb:004:run Running src.prepcache.LunaPrepCacheApp with args: ['--num-workers=4']
# 2026-02-08 19:07:00,546 INFO     pid:476573 src.prepcache:042:main Starting LunaPrepCacheApp, Namespace(batch_size=1024, num_workers=4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 run('src.prepcache.LunaPrepCacheApp')
#
# Cell In[2], line 7, in run(app, *argv)
#       4 log.info(f'Running {app} with args: {argv}')
#       6 app_cls = importstr(*app.rsplit('.', 1))
# ----> 7 app_cls(argv).main()
#       9 log.info(f'Finished running {app}.{argv}.main()')
#
# File ~/Projects/Early_Lung_Cancer_Detection_Using-3DCNN/src/prepcache.py:45, in LunaPrepCacheApp.main(self)
#      41 def main(self):
#      42     log.info("Starting {}, {}".format(type(self).__name__, self.cli_args))
#      44     self.prep_dl = DataLoader(
# ---> 45         LunaDataset(
#      46             sortby_str='series_uid',
#      47         ),
#      48         batch_size=self.cli_args.batch_size,
#      49         num_workers=self.cli_args.num_workers,
#      50     )
#      52     batch_iter = enumerateWithEstimate(
#      53         self.prep_dl,
#      54         "Stuffing cache",
#      55         start_ndx=self.prep_dl.num_workers,
#      56     )
#      57     for _ in batch_iter:
#
# TypeError: LunaDataset.__init__() got an unexpected keyword argument 'sortby_str'
